# %%
import serial

serialPort = serial.Serial(port = "/dev/ttyUSB0", baudrate=115200,
                           bytesize=8, timeout=.1, stopbits=serial.STOPBITS_ONE)

# %%
serialPort.write(b'i')
data = serialPort.readline()
if data:
    print(data)
# Out:
# b'will read an image'

# %%
img_data=[ 
]
